# %% [markdown]
# # Task 1: Read the image Mario and display it like this
#
# ![Screenshot 2024-02-03 at 7.41.56 PM.png](data:image/png;base64,...)
#
# #Task 2: Convert the same image into 2nd display image.
#
#
# #Task 3: Convert the Mario image into Gray Scale.

# %%
#Task 1, 2
from PIL import Image
from IPython.display import display
import sys

try:
    img = Image.open("m.png")
    display(img)

except IOError:
    print("Unable to load image")
    sys.exit(1)
rot2 = img.transpose(Image.ROTATE_180)
display(rot2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=242x240>
# <PIL.Image.Image image mode=RGBA size=242x240>

# %%
# Convert to grayscale
gray_image = img.convert('L')
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=242x240>
